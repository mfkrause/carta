# %% [markdown]
# A bracketed [destination](<two words>) and an angle autolink
# <https://example.com/a^b> are percent-encoded, and so is a bare
# https://example.com/p^q that the notebook dialect autolinks.
